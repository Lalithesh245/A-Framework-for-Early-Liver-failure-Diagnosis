# %% [markdown]
# # Module 2: Exploration of preprocessed and validated data and data visualization

# %%
#import library packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#load dataset
data = pd.read_csv("C:\\Users\\User\\Desktop\\fproject\\dataset\\liver_patient.csv")

# %%
data.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# 1      3.2                        0.74        1
# 2      3.3                        0.89        1
# 3      3.4                        1.00        1
# 4      2.4                        0.40        1

# %%
data.duplicated().sum()
# Out:
# 587

# %%
data = data.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
df=data.dropna()

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'],
#       dtype='object')

# %%
#changing feature name
df = df.rename({'Dataset': 'Result'}, axis=1)

# %%
df['Result'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
pd.Categorical(df['Result']).describe()
# Out:
#             counts     freqs
# categories
# 1              407  0.709059
# 2              167  0.290941

# %%
plt.figure(figsize=(12,7))
plt.title("Affected and Non Affected Liver Patients")
sns.countplot(x='Result',data=df)
# Out:
# <Axes: title={'center': 'Affected and Non Affected Liver Patients'}, xlabel='Result', ylabel='count'>

# %%
df1 = df[df["Result"]==1]
df2 = df[df["Result"]==2]

# %%
df2
# Out:
#       Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 8      17    Male              0.9               0.3                   202
# 12     64    Male              0.8               0.2                   305
# 15     25    Male              0.6               0.1                   183
# 17     33    Male              1.6               0.5                   165
# 24     63    Male              0.9               0.2                   194
# ...   ...     ...              ...               ...                   ...
# 833    61    Male              0.8               0.6                   196
# 862    64    Male              0.9               0.3                   310
# 890    65    Male              1.9               0.8                   170
# 938    65  Female              1.0               0.3                   202
# 1143   65    Male              0.8               0.2                   201
#
#       Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 8                           22                          19             7.4
# 12                          60                          57             6.0
# 15                          91                          53             5.5
# 17                          15                          23             7.3
# 24                          52                          45             6.0
# ...                        ...                         ...             ...
# 833                         61                          85             6.7
# 862                         61                          58             7.0
# 890                         26                          43             3.8
# 938                         26                          13             5.3
# 1143                        26                          22             5.4
#
#       Albumin  Albumin_and_Globulin_Ratio  Result
# 8         4.1                        1.20       2
# 12        3.3                        0.80       2
# 15        2.3                        0.70       2
# 17        3.5                        0.92       2
# 24        3.9                        1.85       2
# ...       ...                         ...     ...
# 833       3.8                        1.30       2
# 862       3.4                        0.90       2
# 890       1.4                        0.58       2
# 938       2.6                        0.90       2
# 1143      2.9                        1.10       2
#
# [167 rows x 11 columns]

# %%
df1
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 803   65    Male              0.7               0.1                   392
# 850   65  Female              0.7               0.1                   187
# 985   61    Male              0.8               0.2                   145
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18             6.8
# 1                          64                         100             7.5
# 2                          60                          68             7.0
# 3                          14                          20             6.8
# 4                          27                          59             7.3
# ..                        ...                         ...             ...
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 803                        26                          30             5.3
# 850                        26                          18             6.8
# 985                        53                          41             5.8
#
#      Albumin  Albumin_and_Globulin_Ratio  Result
# 0        3.3                        0.90       1
# 1        3.2                        0.74       1
# 2        3.3                        0.89       1
# 3        3.4                        1.00       1
# 4        2.4                        0.40       1
# ..       ...                         ...     ...
# 580      3.2                        1.00       1
# 581      3.4                        1.00       1
# 803      2.8                        1.10       1
# 850      3.3                        0.90       1
# 985      2.7                        0.87       1
#
# [407 rows x 11 columns]

# %%
plt.figure(figsize=(8,6))

plt.xlabel("Gender")
plt.ylabel("Count")
plt.hist(df["Gender"],color="red")
plt.title("Liver patients based on Gender")
plt.show()

# %%
df.Result.unique()
# Out:
# array([1, 2], dtype=int64)

# %%
plt.figure(figsize=(10,4))
plt.subplot(1, 2, 1)
plt.hist(df1["Gender"],color="green")
plt.title("Affected people")


plt.subplot(1, 2, 2)
plt.hist(df2["Gender"],color="orange")
plt.title("Not Affected people")

plt.show()

# %%
plt.scatter(df["Albumin"],df["Total_Protiens"])

# %%
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Result
# 0      3.3                        0.90       1
# 1      3.2                        0.74       1
# 2      3.3                        0.89       1
# 3      3.4                        1.00       1
# 4      2.4                        0.40       1

# %%
plt.figure(figsize=(12,6))
plt.plot(df["Albumin_and_Globulin_Ratio"])
plt.show()

# %%
boxplot = df.boxplot(column=['Total_Protiens'], by="Result",figsize=(8,6),  fontsize=15)
boxplot = df.boxplot(column=['Albumin_and_Globulin_Ratio'], by="Result",figsize=(8,6),  fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.scatter(df["Albumin_and_Globulin_Ratio"],df["Result"],color="red")
plt.subplot(1,2,2)
plt.scatter(df["Albumin"],df["Result"],color="red")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
var_mod = ['Result']
le = LabelEncoder()
for i in var_mod:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
var_mod = {'Gender'}
le=LabelEncoder()
for i in var_mod:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
6666
sns.heatmap(df.corr(), ax=ax, annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Result'],
#       dtype='object')
