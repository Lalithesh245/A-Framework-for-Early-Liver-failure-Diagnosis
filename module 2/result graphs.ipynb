# %%
import matplotlib.pyplot as plt

# Set the data for the bar graph
accuracy = [99.411, 96.531, 98.235]
labels = ['MLP', 'SLP', 'Autoencoders']
colors = ['green', 'blue', 'red']

# Set the width of the bars
bar_width = 0.4

# Create the bar graph
fig, ax = plt.subplots()
bars = ax.bar(labels, accuracy, width=bar_width, color=colors)

# Set the title and axis labels
ax.set_title('Accuracy Values')
ax.set_xlabel('DL algorithms')
ax.set_ylabel('Accuracy (%)')

# Add value labels to the bars
for bar in bars:
    height = bar.get_height()
    ax.annotate('{:.3f}'.format(height),
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom', fontsize=8)

# Display the graph
plt.show()

# %%
import matplotlib.pyplot as plt

# Set the data for the bar graph
f1_score = [99.613,98.225,98.850]
labels = ['MLP', 'SLP', 'Autoencoders']
colors = ['green', 'blue', 'red']

# Set the width of the bars
bar_width = 0.4

# Create the bar graph
fig, ax = plt.subplots()
bars = ax.bar(labels, f1_score, width=bar_width, color=colors)

# Set the title and axis labels
ax.set_title('F1 Score Values')
ax.set_xlabel('DL algorithms')
ax.set_ylabel('F1 Score (%)')

# Add value labels to the bars
for bar in bars:
    height = bar.get_height()
    ax.annotate('{:.3f}'.format(height),
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom', fontsize=8)

# Display the graph
plt.show()

# %%
import matplotlib.pyplot as plt

# Set the data for the bar graph
f1_score = [99.230,99.150,97.727]
labels = ['MLP', 'SLP', 'Autoencoders']
colors = ['green', 'blue', 'red']

# Set the width of the bars
bar_width = 0.4

# Create the bar graph
fig, ax = plt.subplots()
bars = ax.bar(labels, f1_score, width=bar_width, color=colors)

# Set the title and axis labels
ax.set_title('Precision Values')
ax.set_xlabel('DL algorithms')
ax.set_ylabel('Precision (%)')

# Add value labels to the bars
for bar in bars:
    height = bar.get_height()
    ax.annotate('{:.3f}'.format(height),
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom', fontsize=8)

# Display the graph
plt.show()

# %%
import matplotlib.pyplot as plt

# Set the data for the bar graph
f1_score = [99.411,96.531,98.235]
labels = ['MLP', 'SLP', 'Autoencoders']
colors = ['green', 'blue', 'red']

# Set the width of the bars
bar_width = 0.4

# Create the bar graph
fig, ax = plt.subplots()
bars = ax.bar(labels, f1_score, width=bar_width, color=colors)

# Set the title and axis labels
ax.set_title('Recall Values')
ax.set_xlabel('DL algorithms')
ax.set_ylabel('Recall (%)')

# Add value labels to the bars
for bar in bars:
    height = bar.get_height()
    ax.annotate('{:.3f}'.format(height),
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom', fontsize=8)

# Display the graph
plt.show()

# %%
import matplotlib.pyplot as plt

# Set the data for the bar graph
dataset = [404,162]
labels = ['Affected', 'Not Affected']
colors = ['green', 'blue']

# Set the width of the bars
bar_width = 0.3

# Create the bar graph
fig, ax = plt.subplots()
bars = ax.bar(labels, dataset, width=bar_width, color=colors)

# Set the title and axis labels
ax.set_title('Affected and Not Affected Liver Patients')
ax.set_xlabel('Results')
ax.set_ylabel('Count')

# Add value labels to the bars
for bar in bars:
    height = bar.get_height()
    ax.annotate('{}'.format(height),
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 2),  # 2 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom', fontsize=8)

# Display the graph

plt.show()

# %%
import matplotlib.pyplot as plt

# Set the data for the bar graph
liver_dataset = [138,428]
labels = ['Female', 'Male']
colors = ['blue', 'red']

# Set the width of the bars
bar_width = 0.3

# Create the bar graph
fig, ax = plt.subplots()
bars = ax.bar(labels, liver_dataset, width=bar_width, color=colors)

# Set the title and axis labels
ax.set_title('Liver Patients Based on Gender')
ax.set_xlabel('Gender')
ax.set_ylabel('Count')

# Add value labels to the bars
for bar in bars:
    height = bar.get_height()
    ax.annotate('{}'.format(height),
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 2),  # 2 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom', fontsize=8)

# Display the graph

plt.show()
